# %%
Tablero = [["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"]
           ]

def mostrar(Tablero):
    print("  a,    b,    c,    d,    e,    f,    g,    h")
    i = 1
    for a in Tablero:
        print(f"{i}{a}")
        i = i + 1

Pieceslist = []
def clear():
    return [["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"]
           ]

pw = []
pb = []
Nw = []
Nb = []
def initgame():
    Tablero = clear()
    pw = []
    pb = []
    for a in range(8):
        pw.append(Pawn(x = [1, a], team = 0))
        pb.append(Pawn(x = [6, a], team = 1))
    Nw = []
    Nb = []
    for a in range(2):
        Nw.append(Knight(x = [0, 1 + 5*a], team = 0))
        Nb.append(Knight(x = [7, 1 + 5*a], team = 1))
    





class Pawn():
    def __init__(self, x = [0, 0], team = 0):
        self.x = x
        self.team = team
        if self.team == 0:
            self.added_string = "w"
        else:
            self.added_string = "b"
        Pieceslist.append(self)
        Tablero[self.x[0]][self.x[1]] = "p" + self.added_string
        if self.team == 1:
            self.stq = 6
        elif self.team == 0:
            self.stq = 1
    def move(self, z = [0, 0]):
        captura = None
        if ((((z[0] == self.x[0] + 1) and (z[1] == self.x[1])) or (((z[1] == self.x[1]) and (z[0] == self.x[0] + 2)) and (self.x[0] == self.stq))) and self.team == 0) or ((((z[0] == self.x[0] - 1) and (z[1] == self.x[1])) or (((z[1] == self.x[1]) and (z[0] == self.x[0] - 2)) and (self.x[0] == self.stq))) and self.team == 1):
            nomou = False
            for a in Pieceslist:
                for b in range(self.x[0] + 1, z[0] + 1):
                    if a.x == [b, z[1]]:
                        nomou = True
            if nomou == True:
                print("invalid")
            else:
                Tablero[self.x[0]][self.x[1]] = "00"
                self.x = z
                Tablero[z[0]][z[1]] = "p" + self.added_string
        # EWn aquest if, comprvo lab la bla
        elif (((z[0] == self.x[0] + 1) and (z[1] == self.x[1] + 1)) or ((z[1] == self.x[1] - 1) and (z[0] == self.x[0] + 1)) and self.team == 0) or (((z[0] == self.x[0] + 1) and (z[1] == self.x[1] - 1)) or ((z[1] == self.x[1] - 1) and (z[0] == self.x[0] - 1)) and self.team == 1):
            nomou = True
            for a in Pieceslist:
                if a.x == z and a.team != self.team:
                    nomou = False
                    captura = a
            if nomou == True:
                print("invalid")
            else:
                Tablero[self.x[0]][self.x[1]] = "00"
                self.x = z
                Tablero[z[0]][z[1]] = "p" + self.added_string
                Pieceslist.remove(captura)
        else:
            print("invalid")
    def falsemove(self, z = [0, 0]):
        # EN aquest IF, comprovo si  bla bla bla
        if ((((z[0] == self.x[0] + 1) and (z[1] == self.x[1])) or (((z[1] == self.x[1]) and (z[0] == self.x[0] + 2)) and (self.x[0] == self.stq))) and self.team == 0) or ((((z[0] == self.x[0] - 1) and (z[1] == self.x[1])) or (((z[1] == self.x[1]) and (z[0] == self.x[0] - 2)) and (self.x[0] == self.stq))) and self.team == 1):
            nomou = False
            for a in Pieceslist:
                for b in range(self.x[0] + 1, z[0] + 1):
                    if a.x == [b, z[1]]:
                        nomou = True
            if nomou == True:
                return False
            else:
                return True
                
        # EWn aquest if, comprvo lab la bla
        elif (((z[0] == self.x[0] + 1) and (z[1] == self.x[1] + 1)) or ((z[1] == self.x[1] - 1) and (z[0] == self.x[0] + 1)) and self.team == 0) or (((z[0] == self.x[0] + 1) and (z[1] == self.x[1] - 1)) or ((z[1] == self.x[1] - 1) and (z[0] == self.x[0] - 1)) and self.team == 1):
            nomou = True
            for a in Pieceslist:
                if a.x == z and a.team != self.team:
                    nomou = False
            if nomou == True:
                return False
            else:
                return True
        else:
            return False

class Knight():
    def __init__(self, x = [0, 0], team = 0):
        self.x = x
        self.team = team
        Pieceslist.append(self)
        if self.team == 0:
            self.added_string = "w"
        else:
            self.added_string = "b"
        Tablero[self.x[0]][self.x[1]] = "N" + self.added_string
    def move(self, z = [0, 0]):
        captura = None
        if (((z[0] == self.x[0] + 1) or (z[0] == self.x[0] - 1)) and ((z[1] == self.x[1] + 2) or (z[1] == self.x[1] - 2))) or (((z[1] == self.x[1] + 2) or (z[1] == self.x[1] - 2)) and ((z[1] == self.x[1] + 1) or (z[1] == self.x[1] - 1))):
            nomou = False
            for a in Pieceslist:
                if a.x == z and a.team == self.team:
                    nomou = True
            if nomou == True:
                print("invalid")
            else:
                Tablero[self.x[0]][self.x[1]] = "00"
                self.x = z
                Tablero[z[0]][z[1]] = "N" + self.added_string
                for a in Pieceslist:
                    if a.x == z and a.team != self.team:
                        Pieceslist.remove(a)

        else:
            print("invalid")
    def falsemove(self, z = [0, 0]):
        if (((z[0] == self.x[0] + 1) or (z[0] == self.x[0] - 1)) and ((z[1] == self.x[1] + 2) or (z[1] == self.x[1] - 2))) or (((z[1] == self.x[1] + 2) or (z[1] == self.x[1] - 2)) and ((z[1] == self.x[1] + 1) or (z[1] == self.x[1] - 1))):
            nomou = False
            for a in Pieceslist:
                if a.x == z and a.team == self.team:
                    nomou = True
            if nomou == True:
                return False
            else:
                return True
        else:
            return False


def demanarmov(N):
    if type(N) != str:
        raise TypeError
    T = [a for a in N]
    if " " in T:
        T.remove(" ")
    if len(T) == 5:
        T = [a if T[0] == a else 0 if a == "a" or a == "1" else 1 if a == "b" or a == "2" else 2 if a == "c" or a == "3" else 3 if a == "d" or a == "4" else 4 if a == "e" or a == "5" else 5 if a == "f" or a == "6" else 6 if a == "g" or a == "7" else 7 if a == "h" or a == "8" else a for a in T]
        for a in Pieceslist:
            if a.x == [T[2], T[1]]:
                if a.falsemove([T[4], T[3]]) == True:
                    if T[0] == "p":
                        if type(a) == Pawn:
                            a.move([T[4], T[3]])
                            return True
                    elif T[0] == "N":
                        if type(a) == Knight:
                            a.move([T[4], T[3]])
                            return True
                    elif T[0] == "B":
                        if type(a) == Bishop:
                            a.move([T[4], T[3]])
                            return True
                    elif T[0] == "R":
                        if type(a) == Rook:
                            a.move([T[4], T[3]])
                            return True
                    elif T[0] == "Q":
                        if type(a) == Queen:
                            a.move([T[4], T[3]])
                            return True
                    elif T[0] == "K":
                        if type(a) == King:
                            a.move([T[4], T[3]])
                            return True
        return False
    elif len(T) == 4:
        T = [0 if a == "a" or a == "1" else 1 if a == "b" or a == "2" else 2 if a == "c" or a == "3" else 3 if a == "d" or a == "4" else 4 if a == "e" or a == "5" else 5 if a == "f" or a == "6" else 6 if a == "g" or a == "7" else 7 if a == "h" or a == "8" else a for a in T]
        for a in Pieceslist:
            if a.x == [T[1], T[0]]:
                if a.falsemove([T[3], T[2]]) == True:
                    if type(a) == Pawn:
                        a.move([T[3], T[2]])
                        return True
        return False
    return False

# %%
Tablero = clear()
Pieceslist = []
N1 = Knight(x = [3, 4], team = 0)
p1 = Pawn(x = [1, 1], team = 0)
p2 = Pawn(x = [1, 4], team = 1)
N2 = Knight(x = [2, 2], team = 1)
print(Pieceslist)
mostrar(Tablero)
print("______________________________________")
N1.move([2, 2])
mostrar(Tablero)
print("______________________________________")
p1.move([3, 1])
mostrar(Tablero)
print("______________________________________")
p2.move([2, 4])
mostrar(Tablero)
print("______________________________________")
# Out:
# [<__main__.Knight object at 0x000001DCBA741BD0>, <__main__.Pawn object at 0x000001DCBA741D10>, <__main__.Pawn object at 0x000001DCBA6B5BA0>, <__main__.Knight object at 0x000001DCBA6B7490>]
#   a,    b,    c,    d,    e,    f,    g,    h
# 1['00', '00', '00', '00', '00', '00', '00', '00']
# 2['00', 'pw', '00', '00', 'pb', '00', '00', '00']
# 3['00', '00', 'Nb', '00', '00', '00', '00', '00']
# 4['00', '00', '00', '00', 'Nw', '00', '00', '00']
# 5['00', '00', '00', '00', '00', '00', '00', '00']
# 6['00', '00', '00', '00', '00', '00', '00', '00']
# 7['00', '00', '00', '00', '00', '00', '00', '00']
# 8['00', '00', '00', '00', '00', '00', '00', '00']
# ______________________________________
#   a,    b,    c,    d,    e,    f,    g,    h
# 1['00', '00', '00', '00', '00', '00', '00', '00']
# 2['00', 'pw', '00', '00', 'pb', '00', '00', '00']
# 3['00', '00', 'Nw', '00', '00', '00', '00', '00']
# 4['00', '00', '00', '00', '00', '00', '00', '00']
# 5['00', '00', '00', '00', '00', '00', '00', '00']
# 6['00', '00', '00', '00', '00', '00', '00', '00']
# 7['00', '00', '00', '00', '00', '00', '00', '00']
# 8['00', '00', '00', '00', '00', '00', '00', '00']
# ______________________________________
#   a,    b,    c,    d,    e,    f,    g,    h
# 1['00', '00', '00', '00', '00', '00', '00', '00']
# 2['00', '00', '00', '00', 'pb', '00', '00', '00']
# 3['00', '00', 'Nw', '00', '00', '00', '00', '00']
# 4['00', 'pw', '00', '00', '00', '00', '00', '00']
# 5['00', '00', '00', '00', '00', '00', '00', '00']
# 6['00', '00', '00', '00', '00', '00', '00', '00']
# 7['00', '00', '00', '00', '00', '00', '00', '00']
# 8['00', '00', '00', '00', '00', '00', '00', '00']
# ______________________________________
# invalid
#   a,    b,    c,    d,    e,    f,    g,    h
# 1['00', '00', '00', '00', '00', '00', '00', '00']
# 2['00', '00', '00', '00', 'pb', '00', '00', '00']
# 3['00', '00', 'Nw', '00', '00', '00', '00', '00']
# 4['00', 'pw', '00', '00', '00', '00', '00', '00']
# 5['00', '00', '00', '00', '00', '00', '00', '00']
# 6['00', '00', '00', '00', '00', '00', '00', '00']
# 7['00', '00', '00', '00', '00', '00', '00', '00']
# 8['00', '00', '00', '00', '00', '00', '00', '00']
# ______________________________________

# %%
Tablero = clear()
Pieceslist = []
p1 = Pawn(x = [1, 1], team = 0)
p2 = Pawn(x = [3, 2], team = 1)
mostrar(Tablero)
p1.move([2,2])
mostrar(Tablero)
p2.move(z = [2,2])
mostrar(Tablero)
p1.move(z = [2,2])
mostrar(Tablero)
# Out:
#   a,    b,    c,    d,    e,    f,    g,    h
# 1['00', '00', '00', '00', '00', '00', '00', '00']
# 2['00', 'pw', '00', '00', '00', '00', '00', '00']
# 3['00', '00', '00', '00', '00', '00', '00', '00']
# 4['00', '00', 'pb', '00', '00', '00', '00', '00']
# 5['00', '00', '00', '00', '00', '00', '00', '00']
# 6['00', '00', '00', '00', '00', '00', '00', '00']
# 7['00', '00', '00', '00', '00', '00', '00', '00']
# 8['00', '00', '00', '00', '00', '00', '00', '00']
# invalid
#   a,    b,    c,    d,    e,    f,    g,    h
# 1['00', '00', '00', '00', '00', '00', '00', '00']
# 2['00', 'pw', '00', '00', '00', '00', '00', '00']
# 3['00', '00', '00', '00', '00', '00', '00', '00']
# 4['00', '00', 'pb', '00', '00', '00', '00', '00']
# 5['00', '00', '00', '00', '00', '00', '00', '00']
# 6['00', '00', '00', '00', '00', '00', '00', '00']
# 7['00', '00', '00', '00', '00', '00', '00', '00']
# 8['00', '00', '00', '00', '00', '00', '00', '00']
#   a,    b,    c,    d,    e,    f,    g,    h
# 1['00', '00', '00', '00', '00', '00', '00', '00']
# 2['00', 'pw', '00', '00', '00', '00', '00', '00']
# 3['00', '00', 'pb', '00', '00', '00', '00', '00']
# 4['00', '00', '00', '00', '00', '00', '00', '00']
# 5['00', '00', '00', '00', '00', '00', '00', '00']
# 6['00', '00', '00', '00', '00', '00', '00', '00']
# 7['00', '00', '00', '00', '00', '00', '00', '00']
# 8['00', '00', '00', '00', '00', '00', '00', '00']
#   a,    b,    c,    d,    e,    f,    g,    h
# 1['00', '00', '00', '00', '00', '00', '00', '00']
# 2['00', '00', '00', '00', '00', '00', '00', '00']
# 3['00', '00', 'pw', '00', '00', '00', '00', '00']
# 4['00', '00', '00', '00', '00', '00', '00', '00']
# 5['00', '00', '00', '00', '00', '00', '00', '00']
# 6['00', '00', '00', '00', '00', '00', '00', '00']
# 7['00', '00', '00', '00', '00', '00', '00', '00']
# 8['00', '00', '00', '00', '00', '00', '00', '00']

# %%
Tablero = clear()
Pieceslist = []
p1 = Pawn(x = [1, 1], team = 0)
p2 = Pawn(x = [2, 1], team = 1)
p3 = Pawn(x = [1, 2], team = 0)
mostrar(Tablero)
p3.move([3,2])
mostrar(Tablero)
p1.move(z = [3,1])
mostrar(Tablero)
# Out:
#   a,    b,    c,    d,    e,    f,    g,    h
# 1['00', '00', '00', '00', '00', '00', '00', '00']
# 2['00', 'pw', 'pw', '00', '00', '00', '00', '00']
# 3['00', 'pb', '00', '00', '00', '00', '00', '00']
# 4['00', '00', '00', '00', '00', '00', '00', '00']
# 5['00', '00', '00', '00', '00', '00', '00', '00']
# 6['00', '00', '00', '00', '00', '00', '00', '00']
# 7['00', '00', '00', '00', '00', '00', '00', '00']
# 8['00', '00', '00', '00', '00', '00', '00', '00']
#   a,    b,    c,    d,    e,    f,    g,    h
# 1['00', '00', '00', '00', '00', '00', '00', '00']
# 2['00', 'pw', '00', '00', '00', '00', '00', '00']
# 3['00', 'pb', '00', '00', '00', '00', '00', '00']
# 4['00', '00', 'pw', '00', '00', '00', '00', '00']
# 5['00', '00', '00', '00', '00', '00', '00', '00']
# 6['00', '00', '00', '00', '00', '00', '00', '00']
# 7['00', '00', '00', '00', '00', '00', '00', '00']
# 8['00', '00', '00', '00', '00', '00', '00', '00']
# invalid
#   a,    b,    c,    d,    e,    f,    g,    h
# 1['00', '00', '00', '00', '00', '00', '00', '00']
# 2['00', 'pw', '00', '00', '00', '00', '00', '00']
# 3['00', 'pb', '00', '00', '00', '00', '00', '00']
# 4['00', '00', 'pw', '00', '00', '00', '00', '00']
# 5['00', '00', '00', '00', '00', '00', '00', '00']
# 6['00', '00', '00', '00', '00', '00', '00', '00']
# 7['00', '00', '00', '00', '00', '00', '00', '00']
# 8['00', '00', '00', '00', '00', '00', '00', '00']

# %%
Tablero = clear()
Pieceslist = []
N3 = Knight(x = [0, 0], team = 0)
p4 = Pawn(x = [1, 1], team = 0)
mostrar(Tablero)
mov = input("moviment")
demanarmov(mov)
mostrar(Tablero)
# Out:
#   a,    b,    c,    d,    e,    f,    g,    h
# 1['Nw', '00', '00', '00', '00', '00', '00', '00']
# 2['00', 'pw', '00', '00', '00', '00', '00', '00']
# 3['00', '00', '00', '00', '00', '00', '00', '00']
# 4['00', '00', '00', '00', '00', '00', '00', '00']
# 5['00', '00', '00', '00', '00', '00', '00', '00']
# 6['00', '00', '00', '00', '00', '00', '00', '00']
# 7['00', '00', '00', '00', '00', '00', '00', '00']
# 8['00', '00', '00', '00', '00', '00', '00', '00']
#   a,    b,    c,    d,    e,    f,    g,    h
# 1['Nw', '00', '00', '00', '00', '00', '00', '00']
# 2['00', '00', '00', '00', '00', '00', '00', '00']
# 3['00', 'pw', '00', '00', '00', '00', '00', '00']
# 4['00', '00', '00', '00', '00', '00', '00', '00']
# 5['00', '00', '00', '00', '00', '00', '00', '00']
# 6['00', '00', '00', '00', '00', '00', '00', '00']
# 7['00', '00', '00', '00', '00', '00', '00', '00']
# 8['00', '00', '00', '00', '00', '00', '00', '00']

# %%
Tablero = clear()
Pieceslist = []
N3 = Knight(x = [0, 0], team = 0)
p4 = Pawn(x = [1, 2], team = 1)
p5 = Pawn(x = [2, 1], team = 0)
mostrar(Tablero)
mostrar(Pieceslist)
mov = input("moviment")
demanarmov(mov)
mostrar(Tablero)
mostrar(Pieceslist)
# Out:
#   a,    b,    c,    d,    e,    f,    g,    h
# 1['Nw', '00', '00', '00', '00', '00', '00', '00']
# 2['00', '00', 'pb', '00', '00', '00', '00', '00']
# 3['00', 'pw', '00', '00', '00', '00', '00', '00']
# 4['00', '00', '00', '00', '00', '00', '00', '00']
# 5['00', '00', '00', '00', '00', '00', '00', '00']
# 6['00', '00', '00', '00', '00', '00', '00', '00']
# 7['00', '00', '00', '00', '00', '00', '00', '00']
# 8['00', '00', '00', '00', '00', '00', '00', '00']
#   a,    b,    c,    d,    e,    f,    g,    h
# 1<__main__.Knight object at 0x000001DCBA54A950>
# 2<__main__.Pawn object at 0x000001DCBAD94EC0>
# 3<__main__.Pawn object at 0x000001DCBAD94E10>
#   a,    b,    c,    d,    e,    f,    g,    h
# 1['00', '00', '00', '00', '00', '00', '00', '00']
# 2['00', '00', 'Nw', '00', '00', '00', '00', '00']
# 3['00', 'pw', '00', '00', '00', '00', '00', '00']
# 4['00', '00', '00', '00', '00', '00', '00', '00']
# 5['00', '00', '00', '00', '00', '00', '00', '00']
# 6['00', '00', '00', '00', '00', '00', '00', '00']
# 7['00', '00', '00', '00', '00', '00', '00', '00']
# 8['00', '00', '00', '00', '00', '00', '00', '00']
#   a,    b,    c,    d,    e,    f,    g,    h
# 1<__main__.Knight object at 0x000001DCBA54A950>
# 2<__main__.Pawn object at 0x000001DCBAD94E10>

# %% [markdown]
# Joc Escacs:

# %%
Player = 0
initgame()
while True:
    mov = False
    mostrar(Tablero)
    while mov == False:
        mov = demanarmov(input(f"el jugador {Player} ha de fer un moviment"))
        if mov == False:
            print("invalid")
    if Player == 0:
        Player = 1
    else:
        Player = 0
    acabar = input("acabar?(Y/N)")
    if(acabar == "Y"):
        break

#NO FUNCIONA
# Out:
#   a,    b,    c,    d,    e,    f,    g,    h
# 1['00', 'Nw', '00', '00', '00', '00', 'Nw', '00']
# 2['pw', 'pw', 'pw', 'pw', 'pw', 'pw', 'pw', 'pw']
# 3['00', '00', '00', '00', '00', '00', '00', '00']
# 4['00', '00', '00', '00', '00', '00', '00', '00']
# 5['00', '00', '00', '00', '00', '00', '00', '00']
# 6['00', '00', '00', '00', '00', '00', '00', '00']
# 7['pb', 'pb', 'pb', 'pb', 'pb', 'pb', 'pb', 'pb']
# 8['00', 'Nb', '00', '00', '00', '00', 'Nb', '00']
# invalid
# invalid
# invalid
# invalid
# invalid
# invalid
# invalid
# invalid
# invalid
# invalid
# invalid
# invalid
# invalid
# invalid
# invalid
#   a,    b,    c,    d,    e,    f,    g,    h
# 1['00', 'Nw', '00', '00', '00', '00', 'Nw', '00']
# 2['pw', 'pw', 'pw', 'pw', '00', 'pw', 'pw', 'pw']
# 3['00', '00', '00', '00', '00', '00', '00', '00']
# 4['00', '00', '00', '00', 'pw', '00', '00', '00']
# 5['00', '00', '00', '00', '00', '00', '00', '00']
# 6['00', '00', '00', '00', '00', '00', '00', '00']
# 7['pb', 'pb', 'pb', 'pb', 'pb', 'pb', 'pb', 'pb']
# 8['00', 'Nb', '00', '00', '00', '00', 'Nb', '00']
#   a,    b,    c,    d,    e,    f,    g,    h
# 1['00', 'Nw', '00', '00', '00', '00', 'Nw', '00']
# 2['pw', 'pw', 'pw', 'pw', '00', 'pw', 'pw', 'pw']
# 3['00', '00', '00', '00', '00', '00', '00', '00']
# 4['00', '00', '00', '00', 'pw', '00', '00', '00']
# 5['00', '00', '00', '00', 'pb', '00', '00', '00']
# 6['00', '00', '00', '00', '00', '00', '00', '00']
# 7['pb', 'pb', 'pb', 'pb', '00', 'pb', 'pb', 'pb']
# 8['00', 'Nb', '00', '00', '00', '00', 'Nb', '00']
# invalid
# invalid
# invalid
# invalid
# invalid
#   a,    b,    c,    d,    e,    f,    g,    h
# 1['00', 'Nw', '00', '00', '00', '00', 'Nw', '00']
# 2['pw', 'pw', 'pw', '00', '00', 'pw', 'pw', 'pw']
# 3['00', '00', '00', '00', '00', '00', '00', '00']
# 4['00', '00', '00', 'pw', 'pw', '00', '00', '00']
# 5['00', '00', '00', '00', 'pb', '00', '00', '00']
# 6['00', '00', '00', '00', '00', '00', '00', '00']
# 7['pb', 'pb', 'pb', 'pb', '00', 'pb', 'pb', 'pb']
# 8['00', 'Nb', '00', '00', '00', '00', 'Nb', '00']
#   a,    b,    c,    d,    e,    f,    g,    h
# 1['00', 'Nw', '00', '00', '00', '00', 'Nw', '00']
# 2['pw', 'pw', 'pw', '00', '00', 'pw', 'pw', 'pw']
# 3['00', '00', '00', '00', '00', '00', '00', '00']
# 4['00', '00', '00', 'pb', 'pw', '00', '00', '00']
# 5['00', '00', '00', '00', '00', '00', '00', '00']
# 6['00', '00', '00', '00', '00', '00', '00', '00']
# 7['pb', 'pb', 'pb', 'pb', '00', 'pb', 'pb', 'pb']
# 8['00', 'Nb', '00', '00', '00', '00', 'Nb', '00']

# %%
Tablero = clear()
Pieceslist = []
Nw1 = Knight(x = [0, 1], team = 0)
mostrar(Tablero)
Nw1.move([1, 3])
mostrar(Tablero)
# Out:
#   a,    b,    c,    d,    e,    f,    g,    h
# 1['00', 'Nw', '00', '00', '00', '00', '00', '00']
# 2['00', '00', '00', '00', '00', '00', '00', '00']
# 3['00', '00', '00', '00', '00', '00', '00', '00']
# 4['00', '00', '00', '00', '00', '00', '00', '00']
# 5['00', '00', '00', '00', '00', '00', '00', '00']
# 6['00', '00', '00', '00', '00', '00', '00', '00']
# 7['00', '00', '00', '00', '00', '00', '00', '00']
# 8['00', '00', '00', '00', '00', '00', '00', '00']
#   a,    b,    c,    d,    e,    f,    g,    h
# 1['00', '00', '00', '00', '00', '00', '00', '00']
# 2['00', '00', '00', 'Nw', '00', '00', '00', '00']
# 3['00', '00', '00', '00', '00', '00', '00', '00']
# 4['00', '00', '00', '00', '00', '00', '00', '00']
# 5['00', '00', '00', '00', '00', '00', '00', '00']
# 6['00', '00', '00', '00', '00', '00', '00', '00']
# 7['00', '00', '00', '00', '00', '00', '00', '00']
# 8['00', '00', '00', '00', '00', '00', '00', '00']
