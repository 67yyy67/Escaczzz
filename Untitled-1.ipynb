# %%
class torre:
    def __init__(self, team=0, x=[0,0]):
        self.x=x
        self.team=team 
        self.taulell=taulell
               
        if self.team == 0:
            self.added_string = "w"
        else:
            self.added_string = "b"
        Pieceslist.append(self)
        taulell[self.x[0]][self.x[1]] = "R" + self.added_string
    def moviments(self,z=[0,0]):
        nomou = False
        if self.x[0] >= 8 or self.x[1] >= 8 or z[0] >= 8 or z[1] >= 8:
            nomou = True
        if (self.x[0]==z[0] or self.x[1]==z[1]) and (self.x != z):
            pass
        else:
            nomou=True

        if self.x[0]==z[0]:
            if z[1]- self.x[1] > 0:
                for i in range(1, z[1]-self.x[1]+1):
                    for a in Pieceslist:
                        if a.x == [self.x[0], self.x[1]+i]:
                            nomou=True
                            return "invalid"    
                        else:
                            pass
           
            if z[1]- self.x[1] < 0: 
                for a in Pieceslist:
                    for i in range(z[1]-self.x[1], 0):
                        if a.x == [self.x[0], self.x[1]+i]:
                            nomou=True
                            return "invalid"    
                        else:
                            pass
        if self.x[1]==z[1]:
            if z[0]- self.x[0] > 0:
                for i in range(1, z[0]-self.x[0]+1):
                    for a in Pieceslist: 
                        if a.x == [self.x[0], self.x[1]+i]:
                            nomou=True
                            return "invalid"    
                        else:
                            pass
            if z[0]- self.x[0] < 0:
                for i in range(z[0]-self.x[0], 0):
                    for a in Pieceslist:
                        if a.x == [self.x[0], self.x[1]+i]:
                            nomou=True
                            return "invalid"    
                        else:
                            pass
        
        dest = taulell[z[0]][z[1]]

        if dest != "00" and dest.endswith(self.added_string):
            print("Aquesta casella està ocupada per una peça pròpia.")
            nomou = True

        if nomou == True:   
            return "invalid"
        else:
            taulell[self.x[0]][self.x[1]] = "00"
            self.x = z
            taulell[z[0]][z[1]] = "R" + self.added_string

# %%
taulell = [["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"]
           ]

def mostrar(taulell):
    print("  a,  b,  c,  d,  e,  f,  g,  h")
    i = 1
    for a in taulell:
        print(f"{i}{a}")
        i = i + 1
def clear():
    return [["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"]
           ]

# %%
taulell = clear()
Pieceslist=[]
rb= torre(x=[2, 2], team=1)
rb2= torre(x=[2,5], team=1)

mostrar(taulell)

rb2.moviments(z=[2,3])
mostrar(taulell)
# Out:
#   a,  b,  c,  d,  e,  f,  g,  h
# 1['00', '00', '00', '00', '00', '00', '00', '00']
# 2['00', '00', '00', '00', '00', '00', '00', '00']
# 3['00', '00', 'Rb', '00', '00', 'Rb', '00', '00']
# 4['00', '00', '00', '00', '00', '00', '00', '00']
# 5['00', '00', '00', '00', '00', '00', '00', '00']
# 6['00', '00', '00', '00', '00', '00', '00', '00']
# 7['00', '00', '00', '00', '00', '00', '00', '00']
# 8['00', '00', '00', '00', '00', '00', '00', '00']
#   a,  b,  c,  d,  e,  f,  g,  h
# 1['00', '00', '00', '00', '00', '00', '00', '00']
# 2['00', '00', '00', '00', '00', '00', '00', '00']
# 3['00', '00', 'Rb', 'Rb', '00', '00', '00', '00']
# 4['00', '00', '00', '00', '00', '00', '00', '00']
# 5['00', '00', '00', '00', '00', '00', '00', '00']
# 6['00', '00', '00', '00', '00', '00', '00', '00']
# 7['00', '00', '00', '00', '00', '00', '00', '00']
# 8['00', '00', '00', '00', '00', '00', '00', '00']

# %%
class alfil:
    def __init__(self, team=0, x=[0,0]):
        self.x=x
        self.team=team 
        self.taulell=taulell
               
        if self.team == 0:
            self.added_string = "w"
        else:
            self.added_string = "b"
        Pieceslist.append(self)
        taulell[self.x[0]][self.x[1]] = "B" + self.added_string


    def moviments(self,z=[0,0]): #x=[1,1] z=[5,5]
        ab=z[0]-self.x[0]
        cd=z[1]-self.x[1]
        nomou = False

        if (self.x[0]-self.x[1]==z[0]-z[1]) or (self.x[0]+self.x[1]==z[0]+z[1]):
           pass
        else:
            nomou=True
             
        if self.x[0] >= 8 or self.x[1] >= 8 or z[0] >= 8 or z[1] >= 8:
            nomou = True
       
        dest = taulell[z[0]][z[1]]

        if dest != "00" and dest.endswith(self.added_string):
            print("Aquesta casella està ocupada per una peça pròpia.")
            nomou = True

        if ab<0 and cd<0:# </ [-,-]
            for i in range(z[0], self.x[0]):
                for a in Pieceslist:
                    if a.x == [i, z[1] + i - z[0]]:
                        nomou=True
                        return "invalid"
                    else:
                        pass
        if ab<0 and cd>0:# <\ [-,+]
            for i in range(z[0], self.x[0]):
                for a in Pieceslist: #arreglar aixo
                    if a.x == [i, z[1] -i + z[0]]:
                        nomou=True
                        return "invalid" 
                    else:
                        pass
        if ab>0 and cd>0:#/> [+,+]
            for i in range(self.x[0] + 1, z[0] + 1):
                for a in Pieceslist:
                    if a.x == [i, self.x[1] + (i - self.x[0])]:
                        nomou=True
                        return "invalid"    
                    else:
                        pass  
        if ab>0 and cd<0:#\> [x,-]
            for i in range(self.x[0] + 1, z[0] + 1):
                for a in Pieceslist:
                    if a.x == [i, self.x[1] - (i - self.x[0])]:
                        nomou=True
                        return "invalid"
                    else:
                        pass
       
       
      
        if nomou == True:
            return "invalid"
        else:
            taulell[self.x[0]][self.x[1]] = "00"
            self.x = z
            taulell[z[0]][z[1]] = "B" + self.added_string

# %%
class alfil:
    def __init__(self, team=0, x=[0,0]):
        self.x=x
        self.team=team 
               
        if self.team == 0:
            self.added_string = "w"
        else:
            self.added_string = "b"
        Pieceslist.append(self)
        taulell[self.x[0]][self.x[1]] = "B" + self.added_string


    def move(self, z = [0, 0]): #x=[1,1] z=[5,5]
        ab = z[0]-self.x[0]
        cd = z[1]-self.x[1]
        nomou = False

        if (self.x[0]-self.x[1] == z[0]-z[1]) or (self.x[0]+self.x[1] == z[0]+z[1]):
           pass
        else:
            nomou = True
             
        if self.x[0] >= 8 or self.x[1] >= 8 or z[0] >= 8 or z[1] >= 8:
            nomou = True
       
        dest = taulell[z[0]][z[1]]

        if dest != "00" and dest[1] == self.added_string:
            print("Aquesta casella està ocupada per una peça pròpia.")
            nomou = True

        if ab<0 and cd<0:# </ [-,-]
            for i in range(z[0] + 1, self.x[0]):
                for a in Pieceslist:
                    if a.x == [i, z[1] + i - z[0] - 1]:
                        nomou=True
                    else:
                        pass
        if ab<0 and cd>0:# <\ [-,+]
            for i in range(z[0] + 1, self.x[0]):
                for a in Pieceslist: 
                    if a.x == [i, z[1] -i + z[0] + 1]:
                        nomou=True
                    else:
                        pass
        if ab>0 and cd>0:#/> [+,+]
            for i in range(self.x[0] + 1, z[0]):
                for a in Pieceslist:
                    if a.x == [i, self.x[1] + 1 + (i - self.x[0] - 1)]:
                        nomou=True    
                    else:
                        pass  
        if ab>0 and cd<0:#\> [+,-]
            for i in range(self.x[0] + 1, z[0]):
                for a in Pieceslist:
                    if a.x == [i, self.x[1] + 1 - (i - self.x[0] - 1)]:
                        nomou=True
                    else:
                        pass
       
       
      
        if nomou == True:
            print("invalid")
        else:
            taulell[self.x[0]][self.x[1]] = "00"
            self.x = z
            taulell[z[0]][z[1]] = "B" + self.added_string
            for a in Pieceslist:
                if a.x == z and a.team != self.team:
                    Pieceslist.remove(a)
        
    def falsemove(self, z = [0, 0]): #x=[1,1] z=[5,5]
        ab = z[0]-self.x[0]
        cd = z[1]-self.x[1]
        nomou = False

        if (self.x[0]-self.x[1] == z[0]-z[1]) or (self.x[0]+self.x[1] == z[0]+z[1]):
           pass
        else:
            nomou = True
             
        if self.x[0] >= 8 or self.x[1] >= 8 or z[0] >= 8 or z[1] >= 8:
            nomou = True
       
        dest = taulell[z[0]][z[1]]

        if dest != "00" and dest[1] == self.added_string:
            print("Aquesta casella està ocupada per una peça pròpia.")
            nomou = True

        if ab<0 and cd<0:# </ [-,-]
            for i in range(z[0] + 1, self.x[0]):
                for a in Pieceslist:
                    if a.x == [i, z[1] + i - z[0] - 1]:
                        nomou=True
                    else:
                        pass
        if ab<0 and cd>0:# <\ [-,+]
            for i in range(z[0] + 1, self.x[0]):
                for a in Pieceslist: #arreglar aixo
                    if a.x == [i, z[1] -i + z[0] + 1]:
                        nomou=True
                    else:
                        pass
        if ab>0 and cd>0:#/> [+,+]
            for i in range(self.x[0] + 1, z[0]):
                for a in Pieceslist:
                    if a.x == [i, self.x[1] + 1 + (i - self.x[0] - 1)]:
                        nomou=True    
                    else:
                        pass  
        if ab>0 and cd<0:#\> [+,-]
            for i in range(self.x[0] + 1, z[0]):
                for a in Pieceslist:
                    if a.x == [i, self.x[1] + 1 - (i - self.x[0] - 1)]:
                        nomou=True
                    else:
                        pass
       
       
      
        if nomou == True:
            return False
        else:
            return True

# %%
taulell = [["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"]
           ]

def mostrar(taulell):
    print("  a,  b,  c,  d,  e,  f,  g,  h")
    i = 1
    for a in taulell:
        print(f"{i}{a}")
        i = i + 1
def clear():
    return [["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"]
           ]

# %%
taulell = clear()

# %%
taulell = clear()

Pieceslist=[]

Bb= alfil(x=[4, 4], team=1)
Bw= alfil(x=[5,5], team=0)

mostrar(taulell)

Bb.move(z=[5,5])

mostrar(taulell)
# Out:
#   a,  b,  c,  d,  e,  f,  g,  h
# 1['00', '00', '00', '00', '00', '00', '00', '00']
# 2['00', '00', '00', '00', '00', '00', '00', '00']
# 3['00', '00', '00', '00', '00', '00', '00', '00']
# 4['00', '00', '00', '00', '00', '00', '00', '00']
# 5['00', '00', '00', '00', 'Bb', '00', '00', '00']
# 6['00', '00', '00', '00', '00', 'Bw', '00', '00']
# 7['00', '00', '00', '00', '00', '00', '00', '00']
# 8['00', '00', '00', '00', '00', '00', '00', '00']
#   a,  b,  c,  d,  e,  f,  g,  h
# 1['00', '00', '00', '00', '00', '00', '00', '00']
# 2['00', '00', '00', '00', '00', '00', '00', '00']
# 3['00', '00', '00', '00', '00', '00', '00', '00']
# 4['00', '00', '00', '00', '00', '00', '00', '00']
# 5['00', '00', '00', '00', '00', '00', '00', '00']
# 6['00', '00', '00', '00', '00', 'Bb', '00', '00']
# 7['00', '00', '00', '00', '00', '00', '00', '00']
# 8['00', '00', '00', '00', '00', '00', '00', '00']

# %%
class reina:
    def __init__(self, team=0, x=[0,0]):
        self.x=x
        self.team=team 
               
        if self.team == 0:
            self.added_string = "w"
        else:
            self.added_string = "b"
        Pieceslist.append(self)
        taulell[self.x[0]][self.x[1]] = "Q" + self.added_string


    def move(self, z = [0, 0]): #x=[1,1] z=[5,5]
        nomou = False
        nomou_alfil = False
        nomou_torre = False
        if self.x[0] >= 8 or self.x[1] >= 8 or z[0] >= 8 or z[1] >= 8:
            nomou = True
        if (self.x[0]==z[0] or self.x[1]==z[1]) and (self.x != z):
            pass
        else:
            nomou_torre=True

        if self.x[0]==z[0]:
            if z[1]- self.x[1] > 0:
                for i in range(1, z[1]-self.x[1]+1):
                    for a in Pieceslist:
                        if a.x == [self.x[0], self.x[1]+i]:
                            nomou_torre=True
                            return "invalid"    
                        else:
                            pass
           
            if z[1]- self.x[1] < 0: 
                for a in Pieceslist:
                    for i in range(z[1]-self.x[1], 0):
                        if a.x == [self.x[0], self.x[1]+i]:
                            nomou_torre=True
                            return "invalid"    
                        else:
                            pass
        if self.x[1]==z[1]:
            if z[0]- self.x[0] > 0:
                for i in range(1, z[0]-self.x[0]+1):
                    for a in Pieceslist: 
                        if a.x == [self.x[0], self.x[1]+i]:
                            nomou_torre=True
                            return "invalid"    
                        else:
                            pass
            if z[0]- self.x[0] < 0:
                for i in range(z[0]-self.x[0], 0):
                    for a in Pieceslist:
                        if a.x == [self.x[0], self.x[1]+i]:
                            nomou_torre=True
                            return "invalid"    
                        else:
                            pass
        
        

        if (self.x[0]-self.x[1] == z[0]-z[1]) or (self.x[0]+self.x[1] == z[0]+z[1]):
           pass
        else:
            nomou_alfil= True
        ab = z[0]-self.x[0]
        cd = z[1]-self.x[1]
        if ab<0 and cd<0:# </ [-,-]
            for i in range(z[0] + 1, self.x[0]):
                for a in Pieceslist:
                    if a.x == [i, z[1] + i - z[0] - 1]:
                        nomou_alfil=True
                    else:
                        pass
        if ab<0 and cd>0:# <\ [-,+]
            for i in range(z[0] + 1, self.x[0]):
                for a in Pieceslist: 
                    if a.x == [i, z[1] -i + z[0] + 1]:
                        nomou_alfil=True
                    else:
                        pass
        if ab>0 and cd>0:#/> [+,+]
            for i in range(self.x[0] + 1, z[0]):
                for a in Pieceslist:
                    if a.x == [i, self.x[1] + 1 + (i - self.x[0] - 1)]:
                        nomou_alfil=True    
                    else:
                        pass  
        if ab>0 and cd<0:#\> [+,-]
            for i in range(self.x[0] + 1, z[0]):
                for a in Pieceslist:
                    if a.x == [i, self.x[1] + 1 - (i - self.x[0] - 1)]:
                        nomou_alfil=True
                    else:
                        pass

        dest = taulell[z[0]][z[1]]

        if dest != "00" and dest.endswith(self.added_string):
            print("Aquesta casella està ocupada per una peça pròpia.")
            nomou = True

        if nomou_torre!=nomou_alfil:
            pass
        else:
            nomou=True
        if nomou == True:   
            return "invalid"
    

            taulell[self.x[0]][self.x[1]] = "00"
            self.x = z
            taulell[z[0]][z[1]] = "Q" + self.added_string
        
        
        else:
            taulell[self.x[0]][self.x[1]] = "00"
            self.x = z
            taulell[z[0]][z[1]] = "Q" + self.added_string

# %%
taulell = [["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"]
           ]

def mostrar(taulell):
    print("  a,  b,  c,  d,  e,  f,  g,  h")
    i = 1
    for a in taulell:
        print(f"{i}{a}")
        i = i + 1
def clear():
    return [["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"],
           ["00", "00", "00", "00", "00", "00", "00", "00"]
           ]

# %%
taulell = clear()

Pieceslist=[]

Qb= reina(x=[4, 4], team=1)
Qw= reina(x=[4,5], team=0)

mostrar(taulell)

Qb.move(z=[4,5])

mostrar(taulell)
# Out:
#   a,  b,  c,  d,  e,  f,  g,  h
# 1['00', '00', '00', '00', '00', '00', '00', '00']
# 2['00', '00', '00', '00', '00', '00', '00', '00']
# 3['00', '00', '00', '00', '00', '00', '00', '00']
# 4['00', '00', '00', '00', '00', '00', '00', '00']
# 5['00', '00', '00', '00', 'Qb', 'Qw', '00', '00']
# 6['00', '00', '00', '00', '00', '00', '00', '00']
# 7['00', '00', '00', '00', '00', '00', '00', '00']
# 8['00', '00', '00', '00', '00', '00', '00', '00']
#   a,  b,  c,  d,  e,  f,  g,  h
# 1['00', '00', '00', '00', '00', '00', '00', '00']
# 2['00', '00', '00', '00', '00', '00', '00', '00']
# 3['00', '00', '00', '00', '00', '00', '00', '00']
# 4['00', '00', '00', '00', '00', '00', '00', '00']
# 5['00', '00', '00', '00', 'Qb', 'Qw', '00', '00']
# 6['00', '00', '00', '00', '00', '00', '00', '00']
# 7['00', '00', '00', '00', '00', '00', '00', '00']
# 8['00', '00', '00', '00', '00', '00', '00', '00']
