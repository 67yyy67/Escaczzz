# %%
Tablero = [["--", "--", "--", "--", "--", "--", "--", "--"],
           ["--", "--", "--", "--", "--", "--", "--", "--"],
           ["--", "--", "--", "--", "--", "--", "--", "--"],
           ["--", "--", "--", "--", "--", "--", "--", "--"],
           ["--", "--", "--", "--", "--", "--", "--", "--"],
           ["--", "--", "--", "--", "--", "--", "--", "--"],
           ["--", "--", "--", "--", "--", "--", "--", "--"],
           ["--", "--", "--", "--", "--", "--", "--", "--"]
           ]

def mostrar(Tablero):
    print("  a,    b,    c,    d,    e,    f,    g,    h")
    i = 1
    for a in Tablero:
        print(f"{i}{a}")
        i = i + 1

Pieceslist = []
def clear():
    return [["--", "--", "--", "--", "--", "--", "--", "--"],
           ["--", "--", "--", "--", "--", "--", "--", "--"],
           ["--", "--", "--", "--", "--", "--", "--", "--"],
           ["--", "--", "--", "--", "--", "--", "--", "--"],
           ["--", "--", "--", "--", "--", "--", "--", "--"],
           ["--", "--", "--", "--", "--", "--", "--", "--"],
           ["--", "--", "--", "--", "--", "--", "--", "--"],
           ["--", "--", "--", "--", "--", "--", "--", "--"]
           ]

pw = []
pb = []
Nw = []
Nb = []
Bw = []
Bb = []
Qw = []
Qb = []
Kw = []
Kb = []
def initgame():
    Tablero = clear()
    pw = []
    pb = []
    for a in range(8):
        pw.append(Pawn(x = [1, a], team = 0))
        pb.append(Pawn(x = [6, a], team = 1))
    Nw = []
    Nb = []
    for a in range(2):
        Nw.append(Knight(x = [0, 1 + 5*a], team = 0))
        Nb.append(Knight(x = [7, 1 + 5*a], team = 1))
    Bw = []
    Bb = []
    for a in range(2):
        Bw.append(alfil(x = [0, 2 + 3*a], team = 0))
        Bb.append(alfil(x = [7, 2 + 3*a], team = 1))
    Rw = []
    Rb = []
    for a in range(2):
        Rw.append(torre(x = [0, 0 + 7*a], team = 0))
        Rb.append(torre(x = [7, 0 + 7*a], team = 1))
    Qw = []
    Qb = []
    Qw.append(reina(x = [0, 3], team = 0))
    Qb.append(reina(x = [7, 3], team = 1))
    Kw = []
    Kb = []
    Kw.append(rei(x = [0, 4], team = 0))
    Kb.append(rei(x = [7, 4], team = 1))

    



class Pawn():
    def __init__(self, x = [0, 0], team = 0):
        self.x = x
        self.team = team
        if self.team == 0:
            self.added_string = "w"
        else:
            self.added_string = "b"
        Pieceslist.append(self)
        Tablero[self.x[0]][self.x[1]] = "p" + self.added_string
        if self.team == 1:
            self.stq = 6
        elif self.team == 0:
            self.stq = 1
    def move(self, z = [0, 0]):
        captura = None
        if ((((z[0] == self.x[0] + 1) and (z[1] == self.x[1])) or (((z[1] == self.x[1]) and (z[0] == self.x[0] + 2)) and (self.x[0] == self.stq))) and self.team == 0) or ((((z[0] == self.x[0] - 1) and (z[1] == self.x[1])) or (((z[1] == self.x[1]) and (z[0] == self.x[0] - 2)) and (self.x[0] == self.stq))) and self.team == 1):
            nomou = False
            for a in Pieceslist:
                for b in range(self.x[0] + 1, z[0] + 1):
                    if a.x == [b, z[1]]:
                        nomou = True
            if nomou == True:
                print("invalid")
            else:
                Tablero[self.x[0]][self.x[1]] = "--"
                self.x = z
                Tablero[z[0]][z[1]] = "p" + self.added_string
                if self.team==0 and self.x[0]==7:
                    Pieceslist.append(reina(x = [7, self.x[1]], team=0))
                    Pieceslist.remove(self)
                elif self.team==1 and self.x[0]==0:
                    Pieceslist.append(reina(x = [0, self.x[1]], team=1))
                    Pieceslist.remove(self)

        # EWn aquest if, comprvo lab la bla
        elif (((z[0] == self.x[0] + 1) and (z[1] == self.x[1] + 1)) or ((z[1] == self.x[1] - 1) and (z[0] == self.x[0] + 1)) and self.team == 0) or (((z[0] == self.x[0] - 1) and (z[1] == self.x[1] + 1)) or ((z[1] == self.x[1] - 1) and (z[0] == self.x[0] - 1)) and self.team == 1):
            nomou = True
            for a in Pieceslist:
                if a.x == z and a.team != self.team:
                    nomou = False
                    Pieceslist.remove(a)
            if nomou == True:
                print("invalid")
            else:
                Tablero[self.x[0]][self.x[1]] = "--"
                self.x = z
                Tablero[z[0]][z[1]] = "p" + self.added_string
                
        else:
            print("invalid")
    def falsemove(self, z = [0, 0]):
        # EN aquest IF, comprovo si  bla bla bla
        if ((((z[0] == self.x[0] + 1) and (z[1] == self.x[1])) or (((z[1] == self.x[1]) and (z[0] == self.x[0] + 2)) and (self.x[0] == self.stq))) and self.team == 0) or ((((z[0] == self.x[0] - 1) and (z[1] == self.x[1])) or (((z[1] == self.x[1]) and (z[0] == self.x[0] - 2)) and (self.x[0] == self.stq))) and self.team == 1):
            nomou = False
            for a in Pieceslist:
                for b in range(self.x[0] + 1, z[0] + 1):
                    if a.x == [b, z[1]]:
                        nomou = True
            if nomou == True:
                return False
            else:
                return True
                
        # EWn aquest if, comprvo lab la bla
        elif (((z[0] == self.x[0] + 1) and (z[1] == self.x[1] + 1)) or ((z[1] == self.x[1] - 1) and (z[0] == self.x[0] + 1)) and self.team == 0) or (((z[0] == self.x[0] - 1) and (z[1] == self.x[1] + 1)) or ((z[1] == self.x[1] - 1) and (z[0] == self.x[0] - 1)) and self.team == 1):
            nomou = True
            for a in Pieceslist:
                if a.x == z and a.team != self.team:
                    nomou = False
            if nomou == True:
                return False
            else:
                return True
        else:
            return False

class Knight():
    def __init__(self, x = [0, 0], team = 0):
        self.x = x
        self.team = team
        Pieceslist.append(self)
        if self.team == 0:
            self.added_string = "w"
        else:
            self.added_string = "b"
        Tablero[self.x[0]][self.x[1]] = "N" + self.added_string
    def move(self, z = [0, 0]):
        captura = None
        if (((z[0] == self.x[0] + 1) or (z[0] == self.x[0] - 1)) and ((z[1] == self.x[1] + 2) or (z[1] == self.x[1] - 2))) or (((z[0] == self.x[0] + 2) or (z[0] == self.x[0] - 2)) and ((z[1] == self.x[1] + 1) or (z[1] == self.x[1] - 1))):
            nomou = False
            for a in Pieceslist:
                if a.x == z and a.team == self.team:
                    nomou = True
            if nomou == True:
                print("invalid")
            else:
                Tablero[self.x[0]][self.x[1]] = "--"
                self.x = z
                Tablero[z[0]][z[1]] = "N" + self.added_string
                for a in Pieceslist:
                    if a.x == z and a.team != self.team:
                        Pieceslist.remove(a)

        else:
            print("invalid")
    def falsemove(self, z = [0, 0]):
        if (((z[0] == self.x[0] + 1) or (z[0] == self.x[0] - 1)) and ((z[1] == self.x[1] + 2) or (z[1] == self.x[1] - 2))) or (((z[0] == self.x[0] + 2) or (z[0] == self.x[0] - 2)) and ((z[1] == self.x[1] + 1) or (z[1] == self.x[1] - 1))):
            nomou = False
            for a in Pieceslist:
                if a.x == z and a.team == self.team:
                    nomou = True
            if nomou == True:
                return False
            else:
                return True
        else:
            return False
        
class alfil:
    def __init__(self, team=0, x=[0,0]):
        self.x=x
        self.team=team 
               
        if self.team == 0:
            self.added_string = "w"
        else:
            self.added_string = "b"
        Pieceslist.append(self)
        Tablero[self.x[0]][self.x[1]] = "B" + self.added_string


    def move(self, z = [0, 0]): #x=[1,1] z=[5,5]
        ab = z[0]-self.x[0]
        cd = z[1]-self.x[1]
        nomou = False

        if (self.x[0]-self.x[1] == z[0]-z[1]) or (self.x[0]+self.x[1] == z[0]+z[1]):
           pass
        else:
            nomou = True
             
        if self.x[0] >= 8 or self.x[1] >= 8 or z[0] >= 8 or z[1] >= 8:
            nomou = True
       
        dest = Tablero[z[0]][z[1]]

        if dest != "--" and dest[1] == self.added_string:
            print("Aquesta casella està ocupada per una peça pròpia.")
            nomou = True

        if ab<0 and cd<0:# </ [-,-]
            for i in range(z[0] + 1, self.x[0]):
                for a in Pieceslist:
                    if a.x == [i, z[1] + (i - z[0])]:
                        nomou=True
                    else:
                        pass
        if ab<0 and cd>0:# <\ [-,+]
            for i in range(z[0] + 1, self.x[0]):
                for a in Pieceslist: #arreglar aixo
                    if a.x == [i, z[1] - (i - z[0])]:
                        nomou=True
                    else:
                        pass
        if ab>0 and cd>0:#/> [+,+]
            for i in range(self.x[0] + 1, z[0]):
                for a in Pieceslist:
                    if a.x == [i, self.x[1] + (i - self.x[0])]:
                        nomou=True    
                    else:
                        pass  
        if ab>0 and cd<0:#\> [+,-]
            for i in range(self.x[0] + 1, z[0]):
                for a in Pieceslist:
                    if a.x == [i, self.x[1] - (i - self.x[0])]:
                        nomou=True
                    else:
                        pass
       
       
      
        if nomou == True:
            print("invalid")
        else:
            Tablero[self.x[0]][self.x[1]] = "--"
            self.x = z
            Tablero[z[0]][z[1]] = "B" + self.added_string
            for a in Pieceslist:
                if a.x == z and a.team != self.team:
                    Pieceslist.remove(a)
        
    def falsemove(self, z = [0, 0]): #x=[1,1] z=[5,5]
        ab = z[0]-self.x[0]
        cd = z[1]-self.x[1]
        nomou = False

        if (self.x[0]-self.x[1] == z[0]-z[1]) or (self.x[0]+self.x[1] == z[0]+z[1]):
           pass
        else:
            nomou = True
             
        if self.x[0] >= 8 or self.x[1] >= 8 or z[0] >= 8 or z[1] >= 8:
            nomou = True
       
        dest = Tablero[z[0]][z[1]]

        if dest != "--" and dest[1] == self.added_string:
            print("Aquesta casella està ocupada per una peça pròpia.")
            nomou = True

        if ab<0 and cd<0:# </ [-,-]
            for i in range(z[0] + 1, self.x[0]):
                for a in Pieceslist:
                    if a.x == [i, z[1] + (i - z[0])]:
                        nomou=True
                    else:
                        pass
        if ab<0 and cd>0:# <\ [-,+]
            for i in range(z[0] + 1, self.x[0]):
                for a in Pieceslist: #arreglar aixo
                    if a.x == [i, z[1] - (i - z[0])]:
                        nomou=True
                    else:
                        pass
        if ab>0 and cd>0:#/> [+,+]
            for i in range(self.x[0] + 1, z[0]):
                for a in Pieceslist:
                    if a.x == [i, self.x[1] + (i - self.x[0])]:
                        nomou=True    
                    else:
                        pass  
        if ab>0 and cd<0:#\> [+,-]
            for i in range(self.x[0] + 1, z[0]):
                for a in Pieceslist:
                    if a.x == [i, self.x[1] - (i - self.x[0])]:
                        nomou=True
                    else:
                        pass

        if nomou == True:
            return False
        else:
            return True
        
class torre:
    def __init__(self, team=0, x=[0,0]):
        self.x=x
        self.team=team 
        self.Tablero=Tablero
               
        if self.team == 0:
            self.added_string = "w"
        else:
            self.added_string = "b"
        Pieceslist.append(self)
        Tablero[self.x[0]][self.x[1]] = "R" + self.added_string
    def move(self,z=[0,0]):
        nomou = False
        if self.x[0] >= 8 or self.x[1] >= 8 or z[0] >= 8 or z[1] >= 8:
            nomou = True
        if (self.x[0]==z[0] or self.x[1]==z[1]) and (self.x != z):
            pass
        else:
            nomou=True

        if self.x[0]==z[0]:
            if z[1]- self.x[1] > 0:
                for i in range(1, z[1]-self.x[1]):
                    for a in Pieceslist:
                        if a.x == [self.x[0], self.x[1]+i]:
                            nomou=True
                            return "invalid"    
                        else:
                            pass
           
            if z[1]- self.x[1] < 0: 
                for a in Pieceslist:
                    for i in range(1, self.x[1]-z[1]):
                        if a.x == [self.x[0], self.x[1]-i]:
                            nomou=True
                            return "invalid"    
                        else:
                            pass
        if self.x[1]==z[1]:
            if z[0]- self.x[0] > 0:
                for i in range(1, z[0]-self.x[0]):
                    for a in Pieceslist: 
                        if a.x == [self.x[0]+i, self.x[1]]:
                            nomou=True
                            return "invalid"    
                        else:
                            pass
            if z[0]- self.x[0] < 0:
                for i in range(1, self.x[0]-z[0]):
                    for a in Pieceslist:
                        if a.x == [self.x[0]-i, self.x[1]]:
                            nomou=True
                            return "invalid"    
                        else:
                            pass
        
        dest = Tablero[z[0]][z[1]]

        if dest != "--" and dest.endswith(self.added_string):
            print("Aquesta casella està ocupada per una peça pròpia.")
            nomou = True

        if nomou == True:   
            return "invalid"
        else:
            Tablero[self.x[0]][self.x[1]] = "--"
            for a in Pieceslist:
                if a.x == z:
                    Pieceslist.remove(a)
            self.x = z
            Tablero[z[0]][z[1]] = "R" + self.added_string
            
    def falsemove(self,z=[0,0]):
        nomou = False
        if self.x[0] >= 8 or self.x[1] >= 8 or z[0] >= 8 or z[1] >= 8:
            nomou = True
        if (self.x[0]==z[0] or self.x[1]==z[1]) and (self.x != z):
            pass
        else:
            nomou=True

        if self.x[0]==z[0]:
            if z[1]- self.x[1] > 0:
                for i in range(1, z[1]-self.x[1]):
                    for a in Pieceslist:
                        if a.x == [self.x[0], self.x[1]+i]:
                            nomou=True
                            return "invalid"    
                        else:
                            pass
           
            if z[1]- self.x[1] < 0: 
                for a in Pieceslist:
                    for i in range(1, self.x[1]-z[1]):
                        if a.x == [self.x[0], self.x[1]-i]:
                            nomou=True
                            return "invalid"    
                        else:
                            pass
        if self.x[1]==z[1]:
            if z[0]- self.x[0] > 0:
                for i in range(1, z[0]-self.x[0]):
                    for a in Pieceslist: 
                        if a.x == [self.x[0]+i, self.x[1]]:
                            nomou=True
                            return "invalid"    
                        else:
                            pass
            if z[0]- self.x[0] < 0:
                for i in range(1, self.x[0]-z[0]):
                    for a in Pieceslist:
                        if a.x == [self.x[0]-i, self.x[1]]:
                            nomou=True
                            return "invalid"    
                        else:
                            pass
        
        dest = Tablero[z[0]][z[1]]

        if dest != "--" and dest.endswith(self.added_string):
            print("Aquesta casella està ocupada per una peça pròpia.")
            nomou = True
            

        if nomou == True:   
            return False
        else:
            return True


class reina:
    def __init__(self, team=0, x=[0,0]):
        self.x=x
        self.team=team 
               
        if self.team == 0:
            self.added_string = "w"
        else:
            self.added_string = "b"
        Pieceslist.append(self)
        Tablero[self.x[0]][self.x[1]] = "Q" + self.added_string


    def move(self, z = [0, 0]): #x=[1,1] z=[5,5]
        nomou = False
        nomou_alfil = False
        nomou_torre = False
        if self.x[0] >= 8 or self.x[1] >= 8 or z[0] >= 8 or z[1] >= 8:
            nomou = True
        if (self.x[0]==z[0] or self.x[1]==z[1]) and (self.x != z):
                    pass
        else: 
                    nomou_torre=True

        if self.x[0]==z[0]:
                            
                            if z[1]- self.x[1] > 0:
                                for i in range(1, z[1]-self.x[1]):
                                    for a in Pieceslist:
                                        if a.x == [self.x[0], self.x[1]+i]:
                                            nomou_torre=True
                            if z[1]- self.x[1] < 0:
                                for i in range(1, self.x[1]-z[1]):
                                    for a in Pieceslist:
                                        if a.x == [self.x[0], self.x[1]-i]:
                                            nomou_torre=True

        if self.x[1]==z[1]:

                            if z[0]- self.x[0] > 0:
                                for i in range(1, z[0]-self.x[0]):
                                    for a in Pieceslist: 
                                        if a.x == [self.x[0]+i, self.x[1]]:
                                            nomou_torre=True
                            if z[0]- self.x[0] < 0:
                                for i in range(1, self.x[0]-z[0]):
                                    for a in Pieceslist:
                                        if a.x == [self.x[0]-i, self.x[1]]:
                                            nomou_torre=True
                                            
        ab = z[0]-self.x[0]
        cd = z[1]-self.x[1]
        if ((self.x[0]-self.x[1] == z[0]-z[1]) or (self.x[0]+self.x[1] == z[0]+z[1])):
                    pass
        else: 
                    nomou_alfil= True
        if ab<0 and cd<0:
            for i in range(z[0] + 1, self.x[0]):
                for a in Pieceslist:
                    if a.x == [i, z[1] + (i - z[0])]:
                        nomou_alfil= True

        if ab<0 and cd>0:  
            for i in range(z[0] + 1, self.x[0]):
                for a in Pieceslist:
                    if a.x == [i, z[1] - (i - z[0])]:
                        nomou_alfil= True

        if ab>0 and cd>0: 
            for i in range(self.x[0] + 1, z[0]):
                for a in Pieceslist:
                    if a.x == [i, self.x[1] + (i - self.x[0])]:
                        nomou_alfil= True

        if ab>0 and cd<0:  
            for i in range(self.x[0] + 1, z[0]):
                for a in Pieceslist:
                    if a.x == [i, self.x[1] - (i - self.x[0])]:
                        nomou_alfil= True

        dest = Tablero[z[0]][z[1]]

        if dest != "--" and dest.endswith(self.added_string):
            print("Aquesta casella està ocupada per una peça pròpia.")
            nomou = True
    
        if nomou_torre!=nomou_alfil:
            pass
        else:
            nomou=True

        if nomou == True:   
            print("invalid")
        else:
            Tablero[self.x[0]][self.x[1]] = "--"
            for a in Pieceslist:
                if a.x == z:
                    Pieceslist.remove(a)
            self.x = z
            Tablero[z[0]][z[1]] = "Q" + self.added_string

    
    def falsemove(self, z = [0, 0]): #x=[1,1] z=[5,5]
        nomou = False
        nomou_alfil = False
        nomou_torre = False
        if self.x[0] >= 8 or self.x[1] >= 8 or z[0] >= 8 or z[1] >= 8:
            nomou = True
        if (self.x[0]==z[0] or self.x[1]==z[1]) and (self.x != z):
                    pass
        else: 
                    nomou_torre=True

        if self.x[0]==z[0]:
                            
                            if z[1]- self.x[1] > 0:
                                for i in range(1, z[1]-self.x[1]):
                                    for a in Pieceslist:
                                        if a.x == [self.x[0], self.x[1]+i]:
                                            nomou_torre=True
                            if z[1]- self.x[1] < 0:
                                for i in range(1, self.x[1]-z[1]):
                                    for a in Pieceslist:
                                        if a.x == [self.x[0], self.x[1]-i]:
                                            nomou_torre=True

        if self.x[1]==z[1]:

                            if z[0]- self.x[0] > 0:
                                for i in range(1, z[0]-self.x[0]):
                                    for a in Pieceslist: 
                                        if a.x == [self.x[0]+i, self.x[1]]:
                                            nomou_torre=True
                            if z[0]- self.x[0] < 0:
                                for i in range(1, self.x[0]-z[0]):
                                    for a in Pieceslist:
                                        if a.x == [self.x[0]-i, self.x[1]]:
                                            nomou_torre=True
                                            
        ab = z[0]-self.x[0]
        cd = z[1]-self.x[1]
        if ((self.x[0]-self.x[1] == z[0]-z[1]) or (self.x[0]+self.x[1] == z[0]+z[1])):
                    pass
        else: 
                    nomou_alfil= True
        if ab<0 and cd<0:
            for i in range(z[0] + 1, self.x[0]):
                for a in Pieceslist:
                    if a.x == [i, z[1] + (i - z[0])]:
                        nomou_alfil= True

        if ab<0 and cd>0:  
            for i in range(z[0] + 1, self.x[0]):
                for a in Pieceslist:
                    if a.x == [i, z[1] - (i - z[0])]:
                        nomou_alfil= True

        if ab>0 and cd>0: 
            for i in range(self.x[0] + 1, z[0]):
                for a in Pieceslist:
                    if a.x == [i, self.x[1] + (i - self.x[0])]:
                        nomou_alfil= True

        if ab>0 and cd<0:  
            for i in range(self.x[0] + 1, z[0]):
                for a in Pieceslist:
                    if a.x == [i, self.x[1] - (i - self.x[0])]:
                        nomou_alfil= True

        dest = Tablero[z[0]][z[1]]

        if dest != "--" and dest.endswith(self.added_string):
            nomou = True
    
        if nomou_torre!=nomou_alfil:
            pass
        else:
            nomou=True

        if nomou == True:   
            return False
        else:
            return True

class rei():
    def __init__(self, x=[0,0], team = 0):
        self.x = x
        self.team = team
        Pieceslist.append(self)
        self.mov_count = 0
        if self.team == 0:
            self.added_string = "w"
        else:
            self.added_string = "b"

        Tablero[self.x[0]][self.x[1]] = "K" + self.added_string
        

    def move(self, z = [0,0]):
        x_aux = self.x 
        captura = None
        if ((z[0] == self.x[0] - 1) and (z[1] == self.x[1]-1)) or ((z[0] == self.x[0]) and (z[1] == self.x[1]-1)) or ((z[0] == self.x[0]+1) and (z[1] == self.x[1]-1)) or ((z[0] == self.x[0]+1) and (z[1] == self.x[1])) or ((z[0] == self.x[0]+1) and (z[1] == self.x[1]+1)) or ((z[0] == self.x[0]) and (z[1] == self.x[1]+1)) or ((z[0] == self.x[0]-1) and (z[1] == self.x[1]+1)) or ((z[0] == self.x[0]-1) and (z[1] == self.x[1])):
                nomou = False  
                for a in Pieceslist:
                    if a.x == z and a.team == self.team:
                        nomou = True
                if nomou == True:
                    print("invalid")
                else:
                    Tablero[self.x[0]][self.x[1]] = "--"
                    self.x = z
                    Tablero[z[0]][z[1]] = "K" + self.added_string
                    self.entras_en_jaque()
                    if self.Perill == True:
                        z = x_aux
                        Tablero[self.x[0]][self.x[1]] = "--"
                        Tablero[z[0]][z[1]] = "K" + self.added_string
                        self.x = z
                        print("Entras en jaque") 
                    else:
                        self.mov_count += 1
                        for a in Pieceslist:
                            if a.x == z and a.team != self.team:
                                Pieceslist.remove(a)
        else:
            print("Invalid2")

    def falsemove(self, z = [0, 0]):
        if ((z[0] == self.x[0] - 1) and (z[1] == self.x[1]-1)) or ((z[0] == self.x[0]) and (z[1] == self.x[1]-1)) or ((z[0] == self.x[0]+1) and (z[1] == self.x[1]-1)) or ((z[0] == self.x[0]+1) and (z[1] == self.x[1])) or ((z[0] == self.x[0]+1) and (z[1] == self.x[1]+1)) or ((z[0] == self.x[0]) and (z[1] == self.x[1]+1)) or ((z[0] == self.x[0]-1) and (z[1] == self.x[1]+1)) or ((z[0] == self.x[0]-1) and (z[1] == self.x[1])) and (self.Perill == False):
            nomou = False
            for a in Pieceslist:
                if a.x == z and a.team == self.team:
                    nomou = True
            if nomou == True:
                return False
            else:
                return True
        else:
            return False
                              
    def entras_en_jaque(self):
        self.Perill = False
        for g in Pieceslist:
            if (isinstance(g, rei)) and (g.team != self.team):
                if (((g.x[0] == self.x[0]-1) and (g.x[1] == self.x[1]-1)) or ((g.x[0] == self.x[0]) and (g.x[1] == self.x[1]-1)) or ((g.x[0] == self.x[0]+1) and (g.x[1] == self.x[1]-1)) or ((g.x[0] == self.x[0]+1) and (g.x[1] == self.x[1])) or ((g.x[0] == self.x[0]+1) and (g.x[1] == self.x[1]+1)) or ((g.x[0] == self.x[0]-1) and (g.x[1] == self.x[1]+1)) or ((g.x[0] == self.x[0]-1) and (g.x[1] == self.x[1])) or ((g.x[0] == self.x[0]) and (g.x[1] == self.x[1]+1))):
                    self.Perill = True
            elif isinstance(g,Pawn) and (g.team != self.team):
                if ((g.x[0]+1 == self.x[0]) and (g.x[1]+1 == self.x[1])) or ((g.x[1]-1 == self.x[1]) and (g.x[0]+1 == self.x[0])) or ((g.x[0]+1 == self.x[0]) and (g.x[1]-1 == self.x[1])) or ((g.x[1]-1 == self.x[1]) and (g.x[0]-1 == self.x[0])):
                    self.Perill = True
            elif isinstance(g,Knight) and (g.team != self.team):
                if ((g.x[0] == self.x[0] + 1) or (g.x[0] == self.x[0] - 1)) and ((g.x[1] == self.x[1] + 2) or (g.x[1] == self.x[1] - 2)) or (((g.x[0] == self.x[0] + 2) or (g.x[0] == self.x[0] - 2)) and ((g.x[1] == self.x[1] + 1) or (g.x[1] == self.x[1] - 1))):
                    self.Perill = True
            elif isinstance(g,alfil) and (g.team != self.team):
                nomou_alfil = False
                nomou_torre = False
                ab = self.x[0]-g.x[0]
                cd = self.x[1]-g.x[1]
                if ((g.x[0]-g.x[1] == self.x[0]-self.x[1]) or (g.x[0]+g.x[1] == self.x[0]+self.x[1])):
                    if ab<0 and cd<0:
                        self.Perill= True
                        for i in range(self.x[0] + 1, g.x[0]):
                            for a in Pieceslist:
                                if a.x == [i, self.x[1] + (i - self.x[0])]:
                                    self.Perill= False

                    if ab<0 and cd>0:  
                        self.Perill= True
                        for i in range(self.x[0] + 1, g.x[0]):
                            for a in Pieceslist:
                                if a.x == [i, self.x[1] - (i - self.x[0])]:
                                    self.Perill= False

                    if ab>0 and cd>0: 
                        self.Perill= True
                        for i in range(g.x[0] + 1, self.x[0]):
                            for a in Pieceslist:
                                if a.x == [i, g.x[1] + (i - g.x[0])]:
                                    self.Perill= False

                    if ab>0 and cd<0:  
                        self.Perill= True
                        for i in range(g.x[0] + 1, self.x[0]):
                            for a in Pieceslist:
                                if a.x == [i, g.x[1] - (i - g.x[0])]:
                                    self.Perill= False
                                    
            elif isinstance(g,torre) and (g.team != self.team):
                if (g.x[0]==self.x[0] or g.x[1]==self.x[1]) and (g.x != self.x):
                        if g.x[0]==self.x[0]:
                            
                            if self.x[1]- g.x[1] > 0:
                                self.Perill= True
                                for i in range(1, self.x[1]-g.x[1]):
                                    for a in Pieceslist:
                                        if a.x == [g.x[0], g.x[1]+i]:
                                            self.Perill= False
                            if self.x[1]- g.x[1] < 0:
                                self.Perill= True
                                for i in range(1, g.x[1]-self.x[1]):
                                    for a in Pieceslist:
                                        if a.x == [g.x[0], g.x[1]-i]:
                                            self.Perill= False

                        if g.x[1]==self.x[1]:

                            if self.x[0]- g.x[0] > 0:
                                self.Perill= True
                                for i in range(1, self.x[0]-g.x[0]):
                                    for a in Pieceslist: 
                                        if a.x == [g.x[0]+i, g.x[1]]:
                                            self.Perill= False
                            if self.x[0]- g.x[0] < 0:
                                self.Perill= True
                                for i in range(1, g.x[0]-self.x[0]):
                                    for a in Pieceslist:
                                        if a.x == [g.x[0]-i, g.x[1]]:
                                            self.Perill= False

            elif isinstance(g,reina) and (g.team != self.team):
                if (g.x[0]==self.x[0] or g.x[1]==self.x[1]) and (g.x != self.x):
                    pass
                else: 
                    nomou_torre=True

                if g.x[0]==self.x[0]:        
                    if self.x[1]- g.x[1] > 0:
                        for i in range(1, self.x[1]-g.x[1]):
                            for a in Pieceslist:
                                if a.x == [g.x[0], g.x[1]+i]:
                                    nomou_torre=True
                    if self.x[1]- g.x[1] < 0:
                        for i in range(1, g.x[1]-self.x[1]):
                            for a in Pieceslist:
                                if a.x == [g.x[0], g.x[1]-i]:
                                    nomou_torre=True

                if g.x[1]==self.x[1]:
                    if self.x[0]- g.x[0] > 0:
                        for i in range(1, self.x[0]-g.x[0]):
                            for a in Pieceslist: 
                                if a.x == [g.x[0]+i, g.x[1]]:
                                    nomou_torre=True
                    if self.x[0]- g.x[0] < 0:
                        for i in range(1, g.x[0]-self.x[0]):
                            for a in Pieceslist:
                                if a.x == [g.x[0]-i, g.x[1]]:
                                    nomou_torre=True

                ab = self.x[0]-g.x[0]
                cd = self.x[1]-g.x[1]
                if ((g.x[0]-g.x[1] == self.x[0]-self.x[1]) or (g.x[0]+g.x[1] == self.x[0]+self.x[1])):
                    pass
                else: 
                    nomou_alfil= True
                if ab<0 and cd<0:
                    for i in range(self.x[0] + 1, g.x[0]):
                        for a in Pieceslist:
                            if a.x == [i, self.x[1] + (i - self.x[0])]:
                                nomou_alfil= True

                if ab<0 and cd>0:  
                    for i in range(self.x[0] + 1, g.x[0]):
                        for a in Pieceslist:
                            if a.x == [i, self.x[1] - (i - self.x[0])]:
                                nomou_alfil= True

                if ab>0 and cd>0: 
                    for i in range(g.x[0] + 1, self.x[0]):
                        for a in Pieceslist:
                            if a.x == [i, g.x[1] + (i - g.x[0])]:
                                nomou_alfil= True

                if ab>0 and cd<0:  
                    for i in range(g.x[0] + 1, self.x[0]):
                        for a in Pieceslist:
                            if a.x == [i, g.x[1] - (i - g.x[0])]:
                                nomou_alfil= True

                if nomou_torre!=nomou_alfil:
                    self.Perill= True
                else:
                    self.Perill= False


def demanarmov(N, j):
    if type(N) != str:
        raise TypeError
    T = [a for a in N]
    if " " in T:
        T.remove(" ")
    if len(T) == 5:
        T = [a if T[0] == a else 0 if a == "a" or a == "1" else 1 if a == "b" or a == "2" else 2 if a == "c" or a == "3" else 3 if a == "d" or a == "4" else 4 if a == "e" or a == "5" else 5 if a == "f" or a == "6" else 6 if a == "g" or a == "7" else 7 if a == "h" or a == "8" else a for a in T]
        for a in Pieceslist:
            if a.x == [T[2], T[1]]:
                if a.falsemove([T[4], T[3]]) == True:
                    if T[0] == "p":
                        if type(a) == Pawn and a.team == j:
                            a.move([T[4], T[3]])
                            return True
                    elif T[0] == "N":
                        if type(a) == Knight and a.team == j:
                            a.move([T[4], T[3]])
                            return True
                    elif T[0] == "B":
                        if type(a) == alfil and a.team == j:
                            a.move([T[4], T[3]])
                            return True
                    elif T[0] == "R":
                        if type(a) == torre and a.team == j:
                            a.move([T[4], T[3]])
                            return True
                    elif T[0] == "Q":
                        if type(a) == reina and a.team == j:
                            a.move([T[4], T[3]])
                            return True
                    elif T[0] == "K":
                        if type(a) == rei and a.team == j:
                            a.move([T[4], T[3]])
                            return True
        return False
    elif len(T) == 4:
        T = [0 if a == "a" or a == "1" else 1 if a == "b" or a == "2" else 2 if a == "c" or a == "3" else 3 if a == "d" or a == "4" else 4 if a == "e" or a == "5" else 5 if a == "f" or a == "6" else 6 if a == "g" or a == "7" else 7 if a == "h" or a == "8" else a for a in T]
        for a in Pieceslist:
            if a.x == [T[1], T[0]]:
                if a.falsemove([T[3], T[2]]) == True and a.team == j:
                    if type(a) == Pawn:
                        a.move([T[3], T[2]])
                        return True
        return False
    return False

# %% [markdown]
# Joc Escacs:

# %%
import tkinter as tk


def mostrar(Tablero):
    texto = "\n      a    b    c    d    e    f    g    h   \n"
    separador = "    +----+----+----+----+----+----+----+----+\n"
    texto += separador
    
    for i, fila in enumerate(Tablero, start=1):
        fila_formateada = " | ".join(pieza.center(2) for pieza in fila)
        texto += f"  {i} | {fila_formateada} |\n"
        texto += separador
        
    return texto

def actualizar_tablero():
    text_tablero.config(state="normal")
    text_tablero.delete("1.0", tk.END)
    text_tablero.insert("1.0", mostrar(Tablero))
    text_tablero.tag_configure("center", justify="center")
    text_tablero.tag_add("center", "1.0", tk.END)
    text_tablero.config(state="disabled")

root = tk.Tk()
root.title("Taulell")
root.configure(bg="#f0f0f0")
root.geometry("800x600") 
text_tablero = tk.Text(
    root,
    font=("Courier", 18, "bold"),
    bg="#2b2b2b",
    fg="#e8e8e8",
    relief="ridge",
    borderwidth=8,
    width=48,  
    height=21  
)
text_tablero.pack(expand=True, pady=20)

frame_mov = tk.Frame(root, bg="#f0f0f0")
frame_mov.pack(pady=5)

label_mov = tk.Label(frame_mov, text="Jugador 0 ha de fer un moviment:", bg="#f0f0f0", font=("Arial", 12))
label_mov.pack(side="left")

entry_mov = tk.Entry(frame_mov, width=25, font=("Arial", 12))
entry_mov.pack(side="left", padx=5)

frame_yn = tk.Frame(root, bg="#f0f0f0")
frame_yn.pack(pady=10)

label_yn = tk.Label(frame_yn, text="Acabar? (Y/N):", bg="#f0f0f0", font=("Arial", 12))
label_yn.pack(side="left")

entry_yn = tk.Entry(frame_yn, width=5, font=("Arial", 12))
entry_yn.pack(side="left", padx=5)

btn_yn = tk.Button(frame_yn, text="OK", font=("Arial", 11, "bold"), cursor="hand2")
btn_yn.pack(side="left", padx=10)

def procesar_movimiento(event=None):
    global Player
    
    jugada = entry_mov.get().strip()
    entry_mov.delete(0, tk.END)

    mov = demanarmov(jugada, Player)
    if not mov:
        label_mov.config(text=f"Jugador {Player}: moviment invàlid")
        return

    for a in Pieceslist:
        if type(a) == rei:
            a.entras_en_jaque()
            if a.Perill and a.team == Player:
                label_mov.config(text="Aquesta jugada et deixa en jaque")
                return

    Player = 1 - Player
    actualizar_tablero()
    label_mov.config(text=f"Jugador {Player} ha de fer un moviment:")

def on_yn_click(event=None):
    resp = entry_yn.get().upper().strip()
    entry_yn.delete(0, tk.END)

    if resp == "Y":
        root.destroy()

Player = 0
Tablero = clear()
Pieceslist = []
initgame()

actualizar_tablero()


entry_mov.bind("<Return>", procesar_movimiento)
btn_yn.config(command=on_yn_click)
entry_yn.bind("<Return>", on_yn_click) 

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 24
#      21     text_tablero.tag_add("center", "1.0", tk.END)
#      22     text_tablero.config(state="disabled")
# ---> 24 root = tk.Tk()
#      25 root.title("Taulell")
#      26 root.configure(bg="#f0f0f0")
#
# File c:\Users\Usuario\AppData\Local\Python\pythoncore-3.14-64\Lib\tkinter\__init__.py:2483, in Tk.__init__(self, screenName, baseName, className, useTk, sync, use)
#    2481     self.tk.settrace(_print_command)
#    2482 if useTk:
# -> 2483     self._loadtk()
#    2484 if not sys.flags.ignore_environment:
#    2485     # Issue #16248: Honor the -E flag to avoid code injection.
#    2486     self.readprofile(baseName, className)
#
# File c:\Users\Usuario\AppData\Local\Python\pythoncore-3.14-64\Lib\tkinter\__init__.py:2512, in Tk._loadtk(self)
#    2510     self._tclCommands = []
# ...

# %%
Player = 0
Tablero = clear()
Pieceslist = []
initgame()
while True:
    Tablero_aux = Tablero
    Pieceslist_aux = Pieceslist
    mov = False
    mostrar(Tablero)
    while mov == False:
        mov = demanarmov(input(f"el jugador {Player} ha de fer un moviment"), Player)
        if mov == False:
            print("invalid")
        else:
            for a in Pieceslist:
                if type(a) == rei:
                    a.entras_en_jaque()
                    if a.Perill == True:
                        print(f"jugador {a.team}, estas en jaque")
                        if a.team == Player:
                            mov = False
                            print("aquesta jugada et deixa en jaque")
                    else:
                        pass
    if Player == 0:
        Player = 1
    else:
        Player = 0
    acabar = input("acabar?(Y/N)")
    if(acabar == "Y"):
        break
# Out:
#   a,    b,    c,    d,    e,    f,    g,    h
# 1['Rw', 'Nw', 'Bw', 'Qw', 'Kw', 'Bw', 'Nw', 'Rw']
# 2['pw', 'pw', 'pw', 'pw', 'pw', 'pw', 'pw', 'pw']
# 3['--', '--', '--', '--', '--', '--', '--', '--']
# 4['--', '--', '--', '--', '--', '--', '--', '--']
# 5['--', '--', '--', '--', '--', '--', '--', '--']
# 6['--', '--', '--', '--', '--', '--', '--', '--']
# 7['pb', 'pb', 'pb', 'pb', 'pb', 'pb', 'pb', 'pb']
# 8['Rb', 'Nb', 'Bb', 'Qb', 'Kb', 'Bb', 'Nb', 'Rb']

# %%
Player = 0
Tablero = clear()
Pieceslist = []
pw1 = Pawn(x = [0, 4], team = 0)
pb1 = Pawn(x = [7, 3], team = 1)
while True:
    Tablero_aux = Tablero
    Pieceslist_aux = Pieceslist
    mov = False
    mostrar(Tablero)
    while mov == False:
        mov = demanarmov(input(f"el jugador {Player} ha de fer un moviment"), Player)
        if mov == False:
            print("invalid")
        else:
            for a in Pieceslist:
                if type(a) == rei:
                    a.entras_en_jaque()
                    if a.Perill == True:
                        print(f"jugador {a.team}, estas en jaque")
                        if a.team == Player:
                            mov = False
                            print("aquesta jugada et deixa en jaque")
                    else:
                        pass
    if Player == 0:
        Player = 1
    else:
        Player = 0
    acabar = input("acabar?(Y/N)")
    if(acabar == "Y"):
        break
# Out:
#   a,    b,    c,    d,    e,    f,    g,    h
# 1['--', '--', '--', '--', 'pw', '--', '--', '--']
# 2['--', '--', '--', '--', '--', '--', '--', '--']
# 3['--', '--', '--', '--', '--', '--', '--', '--']
# 4['--', '--', '--', '--', '--', '--', '--', '--']
# 5['--', '--', '--', '--', '--', '--', '--', '--']
# 6['--', '--', '--', '--', '--', '--', '--', '--']
# 7['--', '--', '--', '--', '--', '--', '--', '--']
# 8['--', '--', '--', 'pb', '--', '--', '--', '--']
#   a,    b,    c,    d,    e,    f,    g,    h
# 1['--', '--', '--', '--', '--', '--', '--', '--']
# 2['--', '--', '--', '--', 'pw', '--', '--', '--']
# 3['--', '--', '--', '--', '--', '--', '--', '--']
# 4['--', '--', '--', '--', '--', '--', '--', '--']
# 5['--', '--', '--', '--', '--', '--', '--', '--']
# 6['--', '--', '--', '--', '--', '--', '--', '--']
# 7['--', '--', '--', '--', '--', '--', '--', '--']
# 8['--', '--', '--', 'pb', '--', '--', '--', '--']
#   a,    b,    c,    d,    e,    f,    g,    h
# ...
